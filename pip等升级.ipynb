# %% [markdown]
# pypi 镜像使用帮助
# pypi 镜像每 5 分钟同步一次。
#
# 临时使用
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple some-package
# 注意，simple 不能少, 是 https 而不是 http
#
# 设为默认
# 升级 pip 到最新的版本 (>=10.0.0) 后进行配置：
#
# pip install pip -U
# pip config set global.index-url https://pypi.tuna.tsinghua.edu.cn/simple
# 如果您到 pip 默认源的网络连接较差，临时使用本镜像站来升级 pip：
#
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pip -U

# %% [markdown]
# *下一条命令无法执行，因为不能传递参数,竟然输入n个\才行*

# %%
c = f"sudo -S pip3 install pyautogui -i https://pypi.tuna.tsinghua.edu.cn/simple selenium"
# !echo \\\\\\\\\\\\\\\\ | $c
# Out:
# Password:WARNING: The directory '/Users/uian/Library/Caches/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/Users/uian/Library/Caches/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      |████████████████████████████████| 61kB 200kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 296kB 13kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 256kB 155kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 122kB 259kB/s eta 0:00:01
# ...

# %%
str = "\\"
print (str * 16 )
str2 = str * 16
print ( len(str2))
# !ls
# !echo $str2 
# !echo $str2 | sudo ls

# %%
str = input()
print (str * 16 )
str2 = str * 16
print ( len(str2))

# !echo $str2
# Out:
# \\
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
# 32
# \\\\\\\\

# %% [markdown]
# # 构造字符串 {}是在循环里的变量

# %%
dataset = ["el","tv"]
model = ["model"]
stride = [32,64,256,512]
for m in model:
    for d in dataset:
        for s in stride:
            #print(f"{m} {d} {s}")
            print (f"tail -n3 N{m}_hp_emb{s}_adam_{d}_log_1.txt")
# Out:
# tail -n3 Nmodel_hp_emb32_adam_el_log_1.txt
# tail -n3 Nmodel_hp_emb64_adam_el_log_1.txt
# tail -n3 Nmodel_hp_emb256_adam_el_log_1.txt
# tail -n3 Nmodel_hp_emb512_adam_el_log_1.txt
# tail -n3 Nmodel_hp_emb32_adam_tv_log_1.txt
# tail -n3 Nmodel_hp_emb64_adam_tv_log_1.txt
# tail -n3 Nmodel_hp_emb256_adam_tv_log_1.txt
# tail -n3 Nmodel_hp_emb512_adam_tv_log_1.txt

# %% [markdown]
# # count是计算字符串里包含某字符几次
# # len是计算字符串长度

# %%
  strings="How do you do"
  
  print(strings.count("do"))
# Out:
# 2

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome()
driver.get("http://www.baidu.com")
print(driver.title)
driver.find_element_by_id("kw").send_keys("selenium")
driver.find_element_by_id("su").click()
time.sleep(3)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Python/3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

# %% [markdown]
# vim 执行shell命令
